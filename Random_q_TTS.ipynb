# %%
# !pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.4.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2023.7.22)
# Installing collected packages: gtts
# Successfully installed gtts-2.4.0

# %%
import pandas as pd
import random
from gtts import gTTS

# 파일 읽어오기
interview = pd.read_excel("interview_by_mj.xlsx")
"""
파일은 다음과 같은 형태로 되어 있다.
AI  지도 학습과 비지도 학습에 대해 설명하시오.  지도 학습은 레이블이 있는...
"""

interview
# Out:
#              분야                                 질문  Unnamed: 2  \
# 0            CS                    컴퓨터의 5가지 구성 요소?         NaN
# 1            CS              쿠키(Cookie), 캐시(Cache)         NaN
# 2            CS             절차지향 프로그래맹, 객체지향 프로그래밍         NaN
# 3            CS     GPU(Graphics Processing Unit)?         NaN
# 4            CS             Git이란?, Git 사용할 줄 아는가?         NaN
# ..          ...                                ...         ...
# 124  Statistics  유의확률이 유의수준보다 작다면? 귀무가설 기각(Yes/No)         NaN
# 125  Statistics  유의확률이 유의수준보다 크다면? 귀무가설 기각(Yes/No)         NaN
# 126  Statistics                            이산 확률분포         NaN
# 127  Statistics                            연속 확률분포         NaN
# 128  Statistics                           조건부 확률분포         NaN
#
#                                                      답  \
# 0    1. CPU(중앙처리장치: 시스템 통제)\n2. RAM(주기억장치: 실행내용 저장)...
# 1    쿠키는 사용자가 웹 사이트를 방문할 때 생성되고 사용자의 컴퓨터에 저장됩니다. 쿠키...
# 2    절차지향 프로그래밍은 일련의 절차나 함수를 사용해서 프로그래밍을 하는 방식입니다. ...
# 3    그래픽 처리 장치로, 주로 그래픽이나 병렬 처리 작업을 수행합니다. 초기에는 2D나...
# 4    Git(분산 버전 관리 시스템)은 소스 코드와 버전을 관리하는 도구입니다. 여러 개...
# ..                                                 ...
# 124  유의확률이 유의수준보다 작다면 귀무가설을 기각하고 대립가설을 받아들입니다. 이는 1...
# 125  유의 확률이 유의수준보다 크다면 귀무가설을 기각하지 않습니다. 이는 유의한 결과를 ...
# 126  이산 확률분포는 확률 변수가 이산적인 값을 가질 때 사용됩니다. 예를 들어, 동전 ...
# 127  연속 확률분포는 확률 변수가 연속 범위 내의 값을 가질 때 사용됩니다. 예를 들어,...
# 128  조건부 확률분포란 어떤 사건이 특정 조건 아래에서 발생할 확률을 설명하는 확률분포입...
#
#                                                  참고 사항
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128  P(A | B) = P(A ∩ B) / P(B)\n: P(A 조건 B)는 P(A와 ...
#
# [129 rows x 5 columns]

# %%
q = interview.iloc[:, 1]
q
# Out:
# 0                        컴퓨터의 5가지 구성 요소?
# 1                  쿠키(Cookie), 캐시(Cache)
# 2                 절차지향 프로그래맹, 객체지향 프로그래밍
# 3         GPU(Graphics Processing Unit)?
# 4                 Git이란?, Git 사용할 줄 아는가?
#                      ...
# 124    유의확률이 유의수준보다 작다면? 귀무가설 기각(Yes/No)
# 125    유의확률이 유의수준보다 크다면? 귀무가설 기각(Yes/No)
# 126                              이산 확률분포
# 127                              연속 확률분포
# 128                             조건부 확률분포
# Name: 질문, Length: 129, dtype: object

# %%
# 무작위로 하나의 행 선택하기
selected_q = q.sample(n=1, random_state=random.seed()).values[0]

# %%
tts = gTTS(text=selected_q, lang='ko')
tts.save("random_question.mp3")
